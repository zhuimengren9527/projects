# %%
import sqlite3
import pandas as pd

data_path = r"C:\projects\machinelearning_study\raw_data\datacamp\SQL\world.db"
conn = sqlite3.connect(data_path)

# %%
# SQL轨道
sql_query = """

"""
df_sql_merged = pd.read_sql_query(sql_query,conn)
print(df_sql_merged)

# %%
# pandas轨道
import pandas as pd
import numpy as np

# 1.读表
