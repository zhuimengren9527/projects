# %%
import pandas as pd
import numpy as np
from pathlib import Path
from pyprojroot import here

# 定位根目录
projects_root = here()


# 创建数据路径
data_path = projects_root/'machinelearning_study'/'raw_data'/'datacamp_study'/'02_olist_brazil_ecommerce'/'olist_orders_dataset.csv'
# Out:
# WindowsPath('d:/projects/machinelearning_study/04_datacamp/clean_data_in_python/chapter_comprehensive_exercises')

# %%
pip install pyprojroot
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyprojroot import here

# 打印出 here() 到底找到了哪里，打破黑盒
print("寻找到的根目录是:", here())
# Out:
# 寻找到的根目录是: d:\projects
